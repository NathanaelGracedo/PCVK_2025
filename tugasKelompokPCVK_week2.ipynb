# %% [markdown]
# <a href="https://colab.research.google.com/github/NathanaelGracedo/PCVK_2025/blob/main/tugasKelompokPCVK_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tugas Kelompok
#
# Tutup tiap bagian tertentu dari KTM tersebut menggunakan fungsi yang telah
# Anda pelajari. Kreasikan terkait dengan warna dan ukuran dari bentuk
# bentuknya.
#
# Kelompok 4 = tulisan Kartu Tanda Mahasiswa dan POLINEMA
# Anggota kelompok:
# 1. Muhammad Afif Al Ghifari - 2341720168 -TI3H-19
# 2. Nathanael Juan Gracedo - 2341720217 - TI3H-24
# 3. Gher

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# tinggal tulis kodenya di bawah

# %% [markdown]
# **KTM AFIF**

# %%
imgAfif =  cv.imread('/content/ktmVirt.png')
ktmAfif = cv.cvtColor(imgAfif, cv.COLOR_BGR2RGB)

cv.rectangle(ktmAfif, pt1=(90,70), pt2=(150,90), color=(255, 0, 255), thickness=-1)
cv.rectangle(ktmAfif, pt1=(50,110), pt2=(300,100), color=(255, 255, 0), thickness=-1)

plt.imshow(ktmAfif)

# %% [markdown]
# **KTM Nathanel Juan Gracedo**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
imgJuan = cv.imread('/content/drive/MyDrive/PCVK_img/KTM-JUAN.jpg')
ktmJuan = cv.cvtColor(imgJuan, cv.COLOR_BGR2RGB)

cv.rectangle(ktmJuan, pt1=(220,120), pt2=(150,130), color=(0, 0, 255), thickness=-1)
cv.rectangle(ktmJuan, pt1=(450,150), pt2=(50,140), color=(255, 0, 0), thickness=-1)

plt.imshow(ktmJuan)
